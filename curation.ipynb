# %%
import gzip
import shutil
import os
import json
import csv

# %% [markdown]
# ## Extracting the image folder

# %%
with gzip.open('abo-images-small/images/metadata/images.csv.gz', 'rb') as f_in:
    with open('abo-images-small/images/metadata/images.csv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

print("Extraction complete.")
# Out:
# Extraction complete.

# %% [markdown]
# ## Extracting the image metadata listings

# %%
# This script extracts .json.gz files from the input directory and saves the decompressed files 
# to the output directory without the .gz extension.

import os
import gzip
import shutil

input_dir = 'abo-listings/listings/metadata/'
output_dir = 'abo-listings/listings/extracted_metadata/'

os.makedirs(output_dir, exist_ok=True)  
for filename in os.listdir(input_dir):
    if filename.endswith('.json.gz'):  # Process only .json.gz files
        input_path = os.path.join(input_dir, filename)
        output_filename = filename[:-3]  # Remove the .gz extension from the filename
        output_path = os.path.join(output_dir, output_filename)

        # Decompress the file
        with gzip.open(input_path, 'rb') as f_in:
            with open(output_path, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out) 
        
        print(f"Extracted {filename} → {output_filename}")

print("All extractions complete.")
# Out:
# Extracted listings_b.json.gz → listings_b.json
# Extracted listings_2.json.gz → listings_2.json
# Extracted listings_c.json.gz → listings_c.json
# Extracted listings_3.json.gz → listings_3.json
# Extracted listings_a.json.gz → listings_a.json
# Extracted listings_1.json.gz → listings_1.json
# Extracted listings_8.json.gz → listings_8.json
# Extracted listings_9.json.gz → listings_9.json
# Extracted listings_0.json.gz → listings_0.json
# Extracted listings_5.json.gz → listings_5.json
# Extracted listings_e.json.gz → listings_e.json
# Extracted listings_4.json.gz → listings_4.json
# Extracted listings_d.json.gz → listings_d.json
# Extracted listings_6.json.gz → listings_6.json
# Extracted listings_f.json.gz → listings_f.json
# Extracted listings_7.json.gz → listings_7.json
# All extractions complete.

# %%
# the extraction is done for all the json listing files

json_dir = 'abo-listings/listings/extracted_metadata/'

for filename in os.listdir(json_dir):
    if filename.endswith('.json'):
        file_path = os.path.join(json_dir, filename)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                content = f.read().strip()
                
                if content.startswith('['):
                    data = json.loads(content)
                    print(f"{filename} loaded as JSON array. Length: {len(data)}")
                else:
                    items = []
                    for line in content.splitlines():
                        line = line.strip()
                        if line:
                            items.append(json.loads(line))
                    print(f"{filename} loaded as {len(items)} separate JSON objects (line by line).")
                    
        except json.JSONDecodeError as e:
            print(f"{filename} failed to load: {e}")
        except Exception as e:
            print(f"{filename} encountered an error: {e}")

print("JSON structure check complete.")
# Out:
# listings_f.json loaded as 9222 separate JSON objects (line by line).
# listings_1.json loaded as 9232 separate JSON objects (line by line).
# listings_0.json loaded as 9232 separate JSON objects (line by line).
# listings_7.json loaded as 9232 separate JSON objects (line by line).
# listings_a.json loaded as 9232 separate JSON objects (line by line).
# listings_6.json loaded as 9232 separate JSON objects (line by line).
# listings_5.json loaded as 9232 separate JSON objects (line by line).
# listings_9.json loaded as 9232 separate JSON objects (line by line).
# listings_b.json loaded as 9232 separate JSON objects (line by line).
# listings_c.json loaded as 9232 separate JSON objects (line by line).
# listings_8.json loaded as 9232 separate JSON objects (line by line).
# listings_4.json loaded as 9232 separate JSON objects (line by line).
# listings_d.json loaded as 9232 separate JSON objects (line by line).
# listings_3.json loaded as 9232 separate JSON objects (line by line).
# listings_2.json loaded as 9232 separate JSON objects (line by line).
# listings_e.json loaded as 9232 separate JSON objects (line by line).
# JSON structure check complete.

# %%
## this was just done to understand the structure of each record in the metadata listing json file

file_path = 'abo-listings/listings/extracted_metadata/listings_1.json'

print(f"Inspecting {file_path}")

with open(file_path, 'r', encoding='utf-8') as f:
    raw = f.read()

print("\n--- First 500 characters ---")
print(raw[:500])
print("\n---------------------------")

try:
    data = json.loads(raw)
    print(" Loaded as single JSON object")
    print(f"Type: {type(data)}")
    if isinstance(data, dict):
        print(f"Top-level keys: {list(data.keys())}")
    elif isinstance(data, list):
        print(f"List length: {len(data)}")
        print(f"First item type: {type(data[0])}")
        if isinstance(data[0], dict):
            print(f"First item keys: {list(data[0].keys())}")
except json.JSONDecodeError as e:
    print(f"Failed to load as single JSON: {e}")

    print("\nTrying to parse line by line...")
    items = []
    for line in raw.splitlines():
        line = line.strip()
        if line:
            try:
                obj = json.loads(line)
                items.append(obj)
            except Exception as sub_e:
                print(f"Failed to parse line: {sub_e}")
                break

    print(f"Parsed {len(items)} JSON objects (line by line)")
    if items:
        print(f"First item type: {type(items[0])}")
        if isinstance(items[0], dict):
            print(f"First item keys: {list(items[0].keys())}")
# Out:
# Inspecting abo-listings/listings/extracted_metadata/listings_1.json
#
# --- First 500 characters ---
# {"brand": [{"language_tag": "en_IN", "value": "Amazon Brand - Solimo"}], "bullet_point": [{"language_tag": "en_IN", "value": "3D Printed Hard Back Case Mobile Cover for Coolpad Cool1 dual"}, {"language_tag": "en_IN", "value": "Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports."}, {"language_tag": "en_IN", "value": "Stylish design and appearance, express your unique personality."}, {"language_tag": "en_IN", "value": "Extreme precision design allows easy access
#
# ---------------------------
# Failed to load as single JSON: Extra data: line 2 column 1 (char 7886)
#
# Trying to parse line by line...
# Parsed 9232 JSON objects (line by line)
# First item type: <class 'dict'>
# First item keys: ['brand', 'bullet_point', 'color', 'item_id', 'item_name', 'item_weight', 'model_name', 'model_number', 'product_type', 'main_image_id', 'other_image_id', 'item_keywords', 'country', 'marketplace', 'domain_name', 'node']

# %% [markdown]
# ## Script for Extracting and Filtering Metadata from JSON Files

# %% [markdown]
# ### This script processes JSON files containing product metadata, filters relevant fields based on specific criteria, and extracts descriptions for generating prompts. The filtered data is saved into a CSV file for further use. It ensures only relevant records with required fields and country-specific data (IN/US) are retained and saved.

# %%
## here, we extract the relevant fields from each record from the json to be included in the final csv which is used for generating the prompts

input_dir = 'abo-listings/listings/extracted_metadata'
output_dir = 'abo-listings/listings/filtered_metadata'

os.makedirs(output_dir, exist_ok=True)

header = [
    'main_image_id', 'overall_description', 'colour_description', 'other_description', 'material_description'
]

# Function to filter 'value' fields by language_tag (or accept if no language_tag)
def get_filtered_values(entries):
    filtered_values = []
    for entry in entries:
        value = entry.get('value')
        language_tag = entry.get('language_tag')
        if value and (language_tag is None or language_tag in ['en_IN', 'en_US']):
            filtered_values.append(value)
    return filtered_values

# Function to filter 'standardized_values' by language_tag (or accept if no language_tag)
def get_filtered_standardized_values(color_entries):
    filtered_values = []
    for entry in color_entries:
        language_tag = entry.get('language_tag')
        if language_tag is None or language_tag in ['en_IN', 'en_US']:
            std_values = entry.get('standardized_values', [])
            filtered_values.extend(std_values)
    return filtered_values

# Process each JSON file in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.json'):
        input_file = os.path.join(input_dir, filename)
        output_file = os.path.join(output_dir, filename.replace('.json', '.csv'))

        print(f"Processing {input_file} → {output_file}")

        # Load line-delimited JSON
        records = []
        with open(input_file, 'r', encoding='utf-8') as f:
            for line in f:
                try:
                    records.append(json.loads(line))
                except json.JSONDecodeError as e:
                    print(f"Failed to load a line in {filename}: {e}")

        required_keys = ['brand', 'bullet_point', 'color', 'model_name', 'item_name', 
                         'product_type', 'main_image_id', 'item_keywords', 'country']

        filtered_records = [
            record for record in records
            if all(key in record for key in required_keys)
            and record.get('country') in ['IN', 'US']
            # and 'item_dimensions' not in record
        ]

        print(f" → Total matching records: {len(filtered_records)}")

        with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(header) 

            for record in filtered_records:
                overall_description = get_filtered_values(record.get('bullet_point', []))
                colour_description = []
                colour_description.extend(get_filtered_standardized_values(record.get('color', [])))
                colour_description.extend(get_filtered_values(record.get('color', [])))
                other_description = []
                for field in ['product_type', 'item_keywords']:
                    other_description.extend(get_filtered_values(record.get(field, [])))
                material_description = []
                if 'material' in record:
                    material_description.extend(get_filtered_values(record.get('material', [])))

                row = [
                    record.get('main_image_id'),
                    '; '.join(overall_description),
                    '; '.join(colour_description),
                    '; '.join(other_description),
                    '; '.join(material_description)
                ]

                writer.writerow(row)

        print(f" → Saved {len(filtered_records)} records to {output_file}\n")
# Out:
# Processing abo-listings/listings/extracted_metadata/listings_f.json → abo-listings/listings/filtered_metadata/listings_f.csv
#  → Total matching records: 4255
#  → Saved 4255 records to abo-listings/listings/filtered_metadata/listings_f.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_1.json → abo-listings/listings/filtered_metadata/listings_1.csv
#  → Total matching records: 4208
#  → Saved 4208 records to abo-listings/listings/filtered_metadata/listings_1.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_0.json → abo-listings/listings/filtered_metadata/listings_0.csv
#  → Total matching records: 4258
#  → Saved 4258 records to abo-listings/listings/filtered_metadata/listings_0.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_7.json → abo-listings/listings/filtered_metadata/listings_7.csv
#  → Total matching records: 4166
#  → Saved 4166 records to abo-listings/listings/filtered_metadata/listings_7.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_a.json → abo-listings/listings/filtered_metadata/listings_a.csv
#  → Total matching records: 4232
#  → Saved 4232 records to abo-listings/listings/filtered_metadata/listings_a.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_6.json → abo-listings/listings/filtered_metadata/listings_6.csv
#  → Total matching records: 4209
#  → Saved 4209 records to abo-listings/listings/filtered_metadata/listings_6.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_5.json → abo-listings/listings/filtered_metadata/listings_5.csv
#  → Total matching records: 4271
#  → Saved 4271 records to abo-listings/listings/filtered_metadata/listings_5.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_9.json → abo-listings/listings/filtered_metadata/listings_9.csv
#  → Total matching records: 4152
#  → Saved 4152 records to abo-listings/listings/filtered_metadata/listings_9.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_b.json → abo-listings/listings/filtered_metadata/listings_b.csv
#  → Total matching records: 4279
#  → Saved 4279 records to abo-listings/listings/filtered_metadata/listings_b.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_c.json → abo-listings/listings/filtered_metadata/listings_c.csv
#  → Total matching records: 4274
#  → Saved 4274 records to abo-listings/listings/filtered_metadata/listings_c.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_8.json → abo-listings/listings/filtered_metadata/listings_8.csv
#  → Total matching records: 4207
#  → Saved 4207 records to abo-listings/listings/filtered_metadata/listings_8.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_4.json → abo-listings/listings/filtered_metadata/listings_4.csv
#  → Total matching records: 4134
#  → Saved 4134 records to abo-listings/listings/filtered_metadata/listings_4.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_d.json → abo-listings/listings/filtered_metadata/listings_d.csv
#  → Total matching records: 4178
#  → Saved 4178 records to abo-listings/listings/filtered_metadata/listings_d.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_3.json → abo-listings/listings/filtered_metadata/listings_3.csv
#  → Total matching records: 4193
#  → Saved 4193 records to abo-listings/listings/filtered_metadata/listings_3.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_2.json → abo-listings/listings/filtered_metadata/listings_2.csv
#  → Total matching records: 4223
#  → Saved 4223 records to abo-listings/listings/filtered_metadata/listings_2.csv
#
# Processing abo-listings/listings/extracted_metadata/listings_e.json → abo-listings/listings/filtered_metadata/listings_e.csv
#  → Total matching records: 4127
#  → Saved 4127 records to abo-listings/listings/filtered_metadata/listings_e.csv

# %%
# !pip install --upgrade pip
# !pip install google-genai
# Out:
# Requirement already satisfied: pip in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (25.1.1)
# Requirement already satisfied: google-genai in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (1.13.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-genai) (2.40.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-genai) (2.11.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-genai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/prana/Desktop/SEM6/VR/venv/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
# from google import genai
# from google.genai import Client, types
# import time

# print(dir(genai))
# print(dir(Client))
# print(dir(types))
# Out:
# ['Client', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_api_client', '_api_module', '_base_url', '_common', '_extra_utils', '_live_converters', '_replay_api_client', '_transformers', 'batches', 'caches', 'chats', 'client', 'errors', 'files', 'live', 'models', 'operations', 'pagers', 'tunings', 'types', 'version']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_get_api_client', 'aio', 'batches', 'caches', 'chats', 'files', 'models', 'operations', 'tunings', 'vertexai']
# ['ActivityEnd', 'ActivityEndDict', 'ActivityEndOrDict', 'ActivityHandling', 'ActivityStart', 'ActivityStartDict', 'ActivityStartOrDict', 'AdapterSize', 'Any', 'AudioTranscriptionConfig', 'AudioTranscriptionConfigDict', 'AudioTranscriptionConfigOrDict', 'AutomaticActivityDetection', 'AutomaticActivityDetectionDict', 'AutomaticActivityDetectionOrDict', 'AutomaticFunctionCallingConfig', 'AutomaticFunctionCallingConfigDict', 'AutomaticFunctionCallingConfigOrDict', 'BatchJob', 'BatchJobDestination', 'BatchJobDestinationDict', 'BatchJobDestinationOrDict', 'BatchJobDict', 'BatchJobOrDict', 'BatchJobSource', 'BatchJobSourceDict', 'BatchJobSourceOrDict', 'Blob', 'BlobDict', 'BlobImageUnion', 'BlobImageUnionDict', 'BlobOrDict', 'BlockedReason', 'CachedContent', 'CachedContentDict', 'CachedContentOrDict', 'CachedContentUsageMetadata', 'CachedContentUsageMetadataDict', 'CachedContentUsageMetadataOrDict', 'Callable', 'CancelBatchJobConfig', 'CancelBatchJobConfigDict', 'CancelBatchJobConfigOrDict', 'Candidate', 'CandidateDict', 'CandidateOrDict', 'Citation', 'CitationDict', 'CitationMetadata', 'CitationMetadataDict', 'CitationMetadataOrDict', 'CitationOrDict', 'CodeExecutionResult', 'CodeExecutionResultDict', 'CodeExecutionResultOrDict', 'ComputeTokensConfig', 'ComputeTokensConfigDict', 'ComputeTokensConfigOrDict', 'ComputeTokensResponse', 'ComputeTokensResponseDict', 'ComputeTokensResponseOrDict', 'Content', 'ContentDict', 'ContentEmbedding', 'ContentEmbeddingDict', 'ContentEmbeddingOrDict', 'ContentEmbeddingStatistics', 'ContentEmbeddingStatisticsDict', 'ContentEmbeddingStatisticsOrDict', 'ContentListUnion', 'ContentListUnionDict', 'ContentOrDict', 'ContentUnion', 'ContentUnionDict', 'ContextWindowCompressionConfig', 'ContextWindowCompressionConfigDict', 'ContextWindowCompressionConfigOrDict', 'ControlReferenceConfig', 'ControlReferenceConfigDict', 'ControlReferenceConfigOrDict', 'ControlReferenceImage', 'ControlReferenceImageDict', 'ControlReferenceImageOrDict', 'ControlReferenceType', 'CountTokensConfig', 'CountTokensConfigDict', 'CountTokensConfigOrDict', 'CountTokensResponse', 'CountTokensResponseDict', 'CountTokensResponseOrDict', 'CreateBatchJobConfig', 'CreateBatchJobConfigDict', 'CreateBatchJobConfigOrDict', 'CreateCachedContentConfig', 'CreateCachedContentConfigDict', 'CreateCachedContentConfigOrDict', 'CreateFileConfig', 'CreateFileConfigDict', 'CreateFileConfigOrDict', 'CreateFileResponse', 'CreateFileResponseDict', 'CreateFileResponseOrDict', 'CreateTuningJobConfig', 'CreateTuningJobConfigDict', 'CreateTuningJobConfigOrDict', 'DatasetDistribution', 'DatasetDistributionDict', 'DatasetDistributionDistributionBucket', 'DatasetDistributionDistributionBucketDict', 'DatasetDistributionDistributionBucketOrDict', 'DatasetDistributionOrDict', 'DatasetStats', 'DatasetStatsDict', 'DatasetStatsOrDict', 'DeleteBatchJobConfig', 'DeleteBatchJobConfigDict', 'DeleteBatchJobConfigOrDict', 'DeleteCachedContentConfig', 'DeleteCachedContentConfigDict', 'DeleteCachedContentConfigOrDict', 'DeleteCachedContentResponse', 'DeleteCachedContentResponseDict', 'DeleteCachedContentResponseOrDict', 'DeleteFileConfig', 'DeleteFileConfigDict', 'DeleteFileConfigOrDict', 'DeleteFileResponse', 'DeleteFileResponseDict', 'DeleteFileResponseOrDict', 'DeleteModelConfig', 'DeleteModelConfigDict', 'DeleteModelConfigOrDict', 'DeleteModelResponse', 'DeleteModelResponseDict', 'DeleteModelResponseOrDict', 'DeleteResourceJob', 'DeleteResourceJobDict', 'DeleteResourceJobOrDict', 'DistillationDataStats', 'DistillationDataStatsDict', 'DistillationDataStatsOrDict', 'DistillationHyperParameters', 'DistillationHyperParametersDict', 'DistillationHyperParametersOrDict', 'DistillationSpec', 'DistillationSpecDict', 'DistillationSpecOrDict', 'DownloadFileConfig', 'DownloadFileConfigDict', 'DownloadFileConfigOrDict', 'DynamicRetrievalConfig', 'DynamicRetrievalConfigDict', 'DynamicRetrievalConfigMode', 'DynamicRetrievalConfigOrDict', 'EditImageConfig', 'EditImageConfigDict', 'EditImageC ...

# %% [markdown]
# ### Script for Generating Image-Based Questions using Gemini API

# %% [markdown]
# #### This script processes listings from a CSV file, retrieves associated images, and queries the Gemini API to generate image-based questions. The generated questions and answers are then saved into a CSV file, with progress tracked to resume from the last processed record if interrupted. Rate limits and daily request constraints are respected to avoid hitting API limits.

# %%
client = genai.Client(api_key="put_the_api_key")

# Set daily limits
MAX_DAILY_REQUESTS = 1500
DELAY_BETWEEN_REQUESTS = 60 

requests_made = 0

def load_progress(progress_file):
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as f:
            index = f.read().strip()
            return int(index)
    return 0

def save_progress(progress_file, index):
    with open(progress_file, 'w') as f:
        f.write(str(index))

def query_gemini_api(image_bytes, combined_description):
    
    # this prompt was used for generating the 5 question-single answer pairs for each image
    prompt_text = (
        "You are given an image and a brief product description.\n"
        f"Use the product description context: {combined_description}\n"
        "Generate exactly 5 diverse, visually clear, and progressively challenging questions.\n"
        "Each question must be answerable by only looking at the image — do NOT rely on external or assumed knowledge.\n"
        "Ensure variation in the *type* of visual cues used: color, shape, count, spatial relationship, relative size, and visible text (if any).\n"
        "Ensure variation in *difficulty level*:\n"
        "- At least 2 simple questions (e.g., color, count)\n"
        "- At least 2 moderately difficult questions (e.g., spatial relations, comparisons)\n"
        "- 1 challenging question requiring closer inspection or subtle visual reasoning (e.g., most prominent item, inferred use from shape)\n"
        "Do NOT ask about materials or properties that are not visually obvious (e.g., plastic, flexible, metal).\n"
        "Answers must be a *single word* — not 'yes' or 'no' unless absolutely necessary.\n"
        "Strictly use this format without extra text:\n"
        "Question 1: <question>\n"
        "Answer 1: <answer>\n"
        "Question 2: <question>\n"
        "Answer 2: <answer>\n"
        "Question 3: <question>\n"
        "Answer 3: <answer>\n"
        "Question 4: <question>\n"
        "Answer 4: <answer>\n"
        "Question 5: <question>\n"
        "Answer 5: <answer>"
    )

    try:
        response = client.models.generate_content(
            model='gemini-2.0-flash',
            contents=[
                types.Part.from_bytes(
                    data=image_bytes,
                    mime_type='image/jpeg'
                ),
                prompt_text
            ]
        )
        return response.text
    except Exception as e:
        print(f"Error querying Gemini API: {e}")
        return None

def process_records(listings_csv_path, images_csv_path, images_base_path, output_file, progress_file):
    global requests_made

    image_path_map = {}
    with open(images_csv_path, 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            image_path_map[row['image_id']] = row['path']

    print("Loaded image metadata successfully.")

    output_dir = os.path.dirname(output_file)
    os.makedirs(output_dir, exist_ok=True)

    # Load last processed index
    start_index = load_progress(progress_file)
    current_index = 0

    with open(output_file, 'a', newline='', encoding='utf-8') as f_out:
        writer = csv.writer(f_out)
        if os.stat(output_file).st_size == 0:
            writer.writerow(['image_id', 'full_image_path', 'question', 'answer'])

        with open(listings_csv_path, 'r', encoding='utf-8') as f_in:
            reader = csv.DictReader(f_in)
            for row in reader:
                if current_index < start_index:
                    current_index += 1
                    continue  # skip already processed

                if requests_made >= MAX_DAILY_REQUESTS:
                    print("Reached daily request limit. Stopping.")
                    break

                image_id = row['main_image_id']
                image_filename = image_path_map.get(image_id)

                if not image_filename:
                    print(f"Image path not found for image_id: {image_id}")
                    current_index += 1
                    continue

                full_image_path = os.path.join(images_base_path, image_filename)

                if not os.path.exists(full_image_path):
                    print(f"Image file does not exist: {full_image_path}")
                    current_index += 1
                    continue

                try:
                    with open(full_image_path, "rb") as img_file:
                        image_bytes = img_file.read()
                except Exception as e:
                    print(f"Failed to read image {full_image_path}: {e}")
                    current_index += 1
                    continue

                combined_description = f"Overall: {row['overall_description']}; " \
                                       f"Color: {row['colour_description']}; " \
                                       f"Material: {row['material_description']}"\
                                       f"Other: {row['other_description']}; " \

                print(f"Sending request for image_id: {image_id}")

                generated_text = query_gemini_api(image_bytes, combined_description)

                if generated_text:
                    lines = [line.strip() for line in generated_text.strip().split('\n') if line.strip()]
                    question_lines = [line for line in lines if line.lower().startswith('question')]
                    answer_lines = [line for line in lines if line.lower().startswith('answer')]

                    if len(question_lines) == 5 and len(answer_lines) == 5:
                        for q_line, a_line in zip(question_lines, answer_lines):
                            question = q_line.split(':', 1)[1].strip()
                            answer = a_line.split(':', 1)[1].strip()
                            writer.writerow([image_id, full_image_path, question, answer])
                            f_out.flush()
                        print(f"Processed image_id: {image_id}")
                    else:
                        print(f"Unexpected format or count in response for image_id: {image_id}")
                else:
                    print(f"Failed to generate questions for image_id: {image_id}")

                requests_made += 1
                current_index += 1
                save_progress(progress_file, current_index)

                if requests_made < MAX_DAILY_REQUESTS:
                    print(f"Sleeping {DELAY_BETWEEN_REQUESTS} seconds to respect rate limits...")
                    time.sleep(DELAY_BETWEEN_REQUESTS)

import os

# CONFIGURATION
current_working_filename = 'listings_a'
question_set_number = 'set_2'


listings_csv_path = f'abo-listings/listings/filtered_metadata/{current_working_filename}.csv'
images_csv_path = 'abo-images-small/images/metadata/images.csv'
images_base_path = 'abo-images-small/images/small'

output_dir = 'generated_questions'
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, f'questions_{current_working_filename}_{question_set_number}.csv')

progress_dir = 'progress'
os.makedirs(progress_dir, exist_ok=True)
progress_file = os.path.join(progress_dir, f'progress_{current_working_filename}.txt')


process_records(listings_csv_path, images_csv_path, images_base_path, output_file, progress_file)
# Out:
# Loaded image metadata successfully.
# Sending request for image_id: 613sLyZDo8L
# Processed image_id: 613sLyZDo8L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 612Ze0tLBSL
# Processed image_id: 612Ze0tLBSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Tj6P5afdL
# Processed image_id: 71Tj6P5afdL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61cI1UAN+8L
# Processed image_id: 61cI1UAN+8L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 715OrnyoT0L
# Processed image_id: 715OrnyoT0L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 711cFmiF4QL
# Processed image_id: 711cFmiF4QL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 715r81595cL
# Processed image_id: 715r81595cL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71v+zZWohsL
# Processed image_id: 71v+zZWohsL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61e+xyLymcL
# Processed image_id: 61e+xyLymcL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71NNWasUWKL
# Processed image_id: 71NNWasUWKL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 51DCuR2JgJL
# Processed image_id: 51DCuR2JgJL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81SnDUXveDL
# Processed image_id: 81SnDUXveDL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81dBkN3K0bL
# Processed image_id: 81dBkN3K0bL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 711JDfL+5BL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 711JDfL+5BL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71li3mHe3pL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71li3mHe3pL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 817Us+roZ7L
# Processed image_id: 817Us+roZ7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71+HZMA6cdL
# Processed image_id: 71+HZMA6cdL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61U38SZYIYL
# Processed image_id: 61U38SZYIYL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Cbebr-haL
# Processed image_id: 71Cbebr-haL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81ykhsC2IUL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 81ykhsC2IUL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61swK+gX9oL
# Processed image_id: 61swK+gX9oL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 819eNb9CcjL
# Processed image_id: 819eNb9CcjL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61-uOcM2ZLL
# Processed image_id: 61-uOcM2ZLL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81rieUqH7IL
# Processed image_id: 81rieUqH7IL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81J-FjY5k5L
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 81J-FjY5k5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61ZniWIYoiL
# Processed image_id: 61ZniWIYoiL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71vxN83u3LL
# Processed image_id: 71vxN83u3LL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71XjLA+fBJL
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 71XjLA+fBJL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71c3l61kI0L
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 71c3l61kI0L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 716Bmwm4EoL
# Processed image_id: 716Bmwm4EoL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61iyGrb9z2L
# Processed image_id: 61iyGrb9z2L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71aIbp64cPL
# Processed image_id: 71aIbp64cPL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81B4RvOfT1L
# Processed image_id: 81B4RvOfT1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 712-5txTN6L
# Processed image_id: 712-5txTN6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71iTRcANfiL
# Processed image_id: 71iTRcANfiL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71LaWT0plGL
# Processed image_id: 71LaWT0plGL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81D8s7MmpqL
# Processed image_id: 81D8s7MmpqL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71n0pjvxvqL
# Processed image_id: 71n0pjvxvqL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71pBFxZnesL
# Processed image_id: 71pBFxZnesL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81WYsaooQVL
# Processed image_id: 81WYsaooQVL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81BVmw+gTSL
# Processed image_id: 81BVmw+gTSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71XJqU9FYGL
# Processed image_id: 71XJqU9FYGL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81nfy04VJbL
# Processed image_id: 81nfy04VJbL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81favg6A17L
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 81favg6A17L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71WJrgZrJXL
# Processed image_id: 71WJrgZrJXL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71P3rTMhxsL
# Processed image_id: 71P3rTMhxsL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61to5xQzKSL
# Processed image_id: 61to5xQzKSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 7185Q3BIeCL
# Processed image_id: 7185Q3BIeCL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81-4+c0HEnL
# Processed image_id: 81-4+c0HEnL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61sIHfuGbpL
# Processed image_id: 61sIHfuGbpL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71oeyQY41CL
# Processed image_id: 71oeyQY41CL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71H6DFiZ2nL
# Processed image_id: 71H6DFiZ2nL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61ZZWX9FLkL
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 61ZZWX9FLkL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71faLgPAHxL
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 71faLgPAHxL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 710sMlvl+CL
# Processed image_id: 710sMlvl+CL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 6189fLPr+sL
# Processed image_id: 6189fLPr+sL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81cMQtB19QL
# Processed image_id: 81cMQtB19QL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81XyZLTmYGL
# Processed image_id: 81XyZLTmYGL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71xoeOoePOL
# Processed image_id: 71xoeOoePOL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61ScKGvu91L
# Processed image_id: 61ScKGvu91L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71S3ex-HOcL
# Processed image_id: 71S3ex-HOcL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71TLQu+qM0L
# Processed image_id: 71TLQu+qM0L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 8147UrUg0nL
# Processed image_id: 8147UrUg0nL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71vwTZFfA8L
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71vwTZFfA8L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 710aZiHgkSL
# Processed image_id: 710aZiHgkSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81+kkHuj3UL
# Processed image_id: 81+kkHuj3UL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71yOatonNfL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71yOatonNfL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61BufgjkEwL
# Processed image_id: 61BufgjkEwL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71wFQGGrf1L
# Processed image_id: 71wFQGGrf1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 617PGDIMW6L
# Processed image_id: 617PGDIMW6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71YHOxC4NAL
# Processed image_id: 71YHOxC4NAL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61uJfVoxfWL
# Processed image_id: 61uJfVoxfWL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81s0eNM2DUL
# Processed image_id: 81s0eNM2DUL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71-eWDCym9L
# Processed image_id: 71-eWDCym9L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71TRvZOh9VL
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 71TRvZOh9VL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81+fmHq26jL
# Processed image_id: 81+fmHq26jL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71QNxhsLrtL
# Processed image_id: 71QNxhsLrtL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71bmUS9ztYL
# Processed image_id: 71bmUS9ztYL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71cxA8j39oL
# Processed image_id: 71cxA8j39oL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61VOAocd5kL
# Processed image_id: 61VOAocd5kL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Soha+-7-L
# Processed image_id: 71Soha+-7-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71LbRhw7cIL
# Processed image_id: 71LbRhw7cIL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71SbVf4216L
# Processed image_id: 71SbVf4216L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71igzW95C7L
# Processed image_id: 71igzW95C7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71qbQKM3jXL
# Processed image_id: 71qbQKM3jXL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81fy3v+2WtL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 81fy3v+2WtL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71seDWbkaFL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71seDWbkaFL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Jd-cG-c+L
# Processed image_id: 71Jd-cG-c+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 717Am-SipJL
# Processed image_id: 717Am-SipJL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71KXre5JbML
# Processed image_id: 71KXre5JbML
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81H8NRkokcL
# Processed image_id: 81H8NRkokcL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 715b+Hb0E+L
# Processed image_id: 715b+Hb0E+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61zeNiUkoFL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 61zeNiUkoFL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71+HkDxyc+L
# Processed image_id: 71+HkDxyc+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61PSTG1tCuL
# Processed image_id: 61PSTG1tCuL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71oksOy0qPL
# Processed image_id: 71oksOy0qPL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61WRSr9Jl2L
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 61WRSr9Jl2L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71zHJ36ffAL
# Processed image_id: 71zHJ36ffAL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71VKFnPMIkL
# Processed image_id: 71VKFnPMIkL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71vrj-R7cnL
# Processed image_id: 71vrj-R7cnL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71xKNjMqjLL
# Processed image_id: 71xKNjMqjLL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71U1rbgfGjL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71U1rbgfGjL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81d8qU+NmRL
# Processed image_id: 81d8qU+NmRL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71NKFF6-eqL
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 71NKFF6-eqL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71PNh1B9ctL
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 71PNh1B9ctL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81eU2CORINL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 81eU2CORINL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61hN+zdKKRL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 61hN+zdKKRL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 8108PJHe6JL
# Processed image_id: 8108PJHe6JL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81YYOxCTcGL
# Processed image_id: 81YYOxCTcGL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61+NaH67T0L
# Processed image_id: 61+NaH67T0L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Rq+Ne8hGL
# Processed image_id: 71Rq+Ne8hGL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71PFaAnuNaL
# Processed image_id: 71PFaAnuNaL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61c9OOWe4KL
# Processed image_id: 61c9OOWe4KL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Dr3Od36GL
# Processed image_id: 71Dr3Od36GL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71fCAu5qr6L
# Processed image_id: 71fCAu5qr6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 719ifvCgLlL
# Processed image_id: 719ifvCgLlL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61BjHsVtzrL
# Processed image_id: 61BjHsVtzrL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 717cicUE4wL
# Processed image_id: 717cicUE4wL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71bO40PZJZL
# Processed image_id: 71bO40PZJZL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71MbhjNQX0L
# Processed image_id: 71MbhjNQX0L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81vfYiDKB8L
# Error querying Gemini API: [Errno 8] nodename nor servname provided, or not known
# Failed to generate questions for image_id: 81vfYiDKB8L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 610agbuL2kL
# Error querying Gemini API: [Errno 8] nodename nor servname provided, or not known
# Failed to generate questions for image_id: 610agbuL2kL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61u+OLtlqXL
# Error querying Gemini API: [Errno 8] nodename nor servname provided, or not known
# Failed to generate questions for image_id: 61u+OLtlqXL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61AyWtnYt5L
# Error querying Gemini API: [Errno 8] nodename nor servname provided, or not known
# Failed to generate questions for image_id: 61AyWtnYt5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61Ihyu6JpSL
# Error querying Gemini API: [Errno 8] nodename nor servname provided, or not known
# Failed to generate questions for image_id: 61Ihyu6JpSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71nJdoL5A6L
# Error querying Gemini API: [Errno 8] nodename nor servname provided, or not known
# Failed to generate questions for image_id: 71nJdoL5A6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81aTtVV2+zL
# Processed image_id: 81aTtVV2+zL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71onx8hB3pL
# Processed image_id: 71onx8hB3pL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71y+rJGACxL
# Processed image_id: 71y+rJGACxL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 811capfpsvL
# Processed image_id: 811capfpsvL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61qj2f4b4jL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 61qj2f4b4jL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61XDFIANOfL
# Processed image_id: 61XDFIANOfL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Qab4KrAsL
# Processed image_id: 71Qab4KrAsL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71AdKrNAuNL
# Processed image_id: 71AdKrNAuNL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 31Dzqdw8rwL
# Processed image_id: 31Dzqdw8rwL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81J0525X2eL
# Processed image_id: 81J0525X2eL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61iISiWY5wL
# Processed image_id: 61iISiWY5wL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71L0sxpR7KL
# Processed image_id: 71L0sxpR7KL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ZVz3dnXoL
# Processed image_id: 71ZVz3dnXoL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71A7Zb6t53L
# Processed image_id: 71A7Zb6t53L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 710IMB2AZiL
# Processed image_id: 710IMB2AZiL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61jmQt-8zvL
# Processed image_id: 61jmQt-8zvL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71CK2LG64+L
# Processed image_id: 71CK2LG64+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 710NUzPKSlL
# Processed image_id: 710NUzPKSlL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Fw8zeiuvL
# Processed image_id: 71Fw8zeiuvL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71HRCB+tVcL
# Processed image_id: 71HRCB+tVcL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61ZlfxRAeLL
# Processed image_id: 61ZlfxRAeLL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71+uylPug1L
# Processed image_id: 71+uylPug1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 714cm6kBt5L
# Processed image_id: 714cm6kBt5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ab2XECTWL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71ab2XECTWL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81wCmj96FPL
# Processed image_id: 81wCmj96FPL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61EmobNCIPL
# Processed image_id: 61EmobNCIPL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81oBOJzEK4L
# Processed image_id: 81oBOJzEK4L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61V-oL204fL
# Processed image_id: 61V-oL204fL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81SKcJu6n7L
# Processed image_id: 81SKcJu6n7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 710BElxXnBL
# Processed image_id: 710BElxXnBL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71eiR0rRAKL
# Processed image_id: 71eiR0rRAKL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71i+oDHIEfL
# Processed image_id: 71i+oDHIEfL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71lj23TpaVL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71lj23TpaVL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81QYe8OiTrL
# Processed image_id: 81QYe8OiTrL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81uRG1CgtoL
# Processed image_id: 81uRG1CgtoL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71zYbXACfjL
# Processed image_id: 71zYbXACfjL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71lQbBwLZWL
# Processed image_id: 71lQbBwLZWL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81MKLm7NQBL
# Processed image_id: 81MKLm7NQBL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81Ww8QDzkDL
# Processed image_id: 81Ww8QDzkDL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71vYBD2vADL
# Processed image_id: 71vYBD2vADL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71PUOMUzBvL
# Processed image_id: 71PUOMUzBvL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71seOTZ0isL
# Processed image_id: 71seOTZ0isL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81hie20SbnL
# Processed image_id: 81hie20SbnL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81TJnfb8R9L
# Processed image_id: 81TJnfb8R9L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 51W446lzzFL
# Processed image_id: 51W446lzzFL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71mVtSfA+pL
# Processed image_id: 71mVtSfA+pL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71sTazND+1L
# Processed image_id: 71sTazND+1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81OWvAn4hFL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 81OWvAn4hFL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81oigt-r-uL
# Processed image_id: 81oigt-r-uL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71tgocvQnPL
# Processed image_id: 71tgocvQnPL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71v9fH32mSL
# Processed image_id: 71v9fH32mSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71YNU9wYMcL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71YNU9wYMcL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81xIg+nKDFL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 81xIg+nKDFL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71I7TlFDooL
# Processed image_id: 71I7TlFDooL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71WQlmjzqEL
# Processed image_id: 71WQlmjzqEL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71BlhVIwqML
# Processed image_id: 71BlhVIwqML
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 611-wlTe8nL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 611-wlTe8nL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71gO7TmTSlL
# Processed image_id: 71gO7TmTSlL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71KW7LGeeWL
# Processed image_id: 71KW7LGeeWL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71+qMxHAhkL
# Processed image_id: 71+qMxHAhkL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81SJRY-ly-L
# Processed image_id: 81SJRY-ly-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71CSExt0uQL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71CSExt0uQL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61bb-DyYmZL
# Processed image_id: 61bb-DyYmZL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ejQRkXwsL
# Processed image_id: 71ejQRkXwsL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71EREdKykNL
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 71EREdKykNL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ytH-FVi-L
# Error querying Gemini API: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# Failed to generate questions for image_id: 71ytH-FVi-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 714cvDusx1L
# Processed image_id: 714cvDusx1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61IFHPdaIRL
# Processed image_id: 61IFHPdaIRL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71BMPWE27qL
# Processed image_id: 71BMPWE27qL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81PtsJ5i5CL
# Processed image_id: 81PtsJ5i5CL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81HljjtznVL
# Processed image_id: 81HljjtznVL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71PFalu0LhL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71PFalu0LhL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71A0Xi8duKL
# Processed image_id: 71A0Xi8duKL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 712z3uJhG6L
# Processed image_id: 712z3uJhG6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81uoleQrefL
# Processed image_id: 81uoleQrefL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ZtIShTLNL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 71ZtIShTLNL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71N4QrpLPhL
# Processed image_id: 71N4QrpLPhL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Xp+giBQiL
# Processed image_id: 71Xp+giBQiL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71gh7-ByfCL
# Processed image_id: 71gh7-ByfCL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61+pWucMhyL
# Processed image_id: 61+pWucMhyL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71yYTj0HoaL
# Processed image_id: 71yYTj0HoaL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 818clGDAAvL
# Error querying Gemini API: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'Resource has been exhausted (e.g. check quota).', 'status': 'RESOURCE_EXHAUSTED'}}
# Failed to generate questions for image_id: 818clGDAAvL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61E2kE9WlXL
# Processed image_id: 61E2kE9WlXL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71vQoOiSBrL
# Processed image_id: 71vQoOiSBrL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61bsZG77pwL
# Processed image_id: 61bsZG77pwL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71qBaJQm6YL
# Processed image_id: 71qBaJQm6YL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71h09AXQKOL
# Processed image_id: 71h09AXQKOL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 813LcOzW8vL
# Processed image_id: 813LcOzW8vL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61t9l-LSinL
# Processed image_id: 61t9l-LSinL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71AG+DiHg5L
# Processed image_id: 71AG+DiHg5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71WFQdABoML
# Processed image_id: 71WFQdABoML
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71y1AIdJ0hL
# Processed image_id: 71y1AIdJ0hL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81ABLVEprwL
# Processed image_id: 81ABLVEprwL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71frDsgSVFL
# Processed image_id: 71frDsgSVFL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71nuGLdA12L
# Processed image_id: 71nuGLdA12L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 711S1mRaeBL
# Processed image_id: 711S1mRaeBL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81jxsyeW9EL
# Processed image_id: 81jxsyeW9EL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71lIja1kKSL
# Processed image_id: 71lIja1kKSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71u4E6+++FL
# Processed image_id: 71u4E6+++FL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61NdFCnZvUL
# Processed image_id: 61NdFCnZvUL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81GMrPCPs4L
# Processed image_id: 81GMrPCPs4L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61HHOm0uhpL
# Processed image_id: 61HHOm0uhpL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71joLhJNd3L
# Processed image_id: 71joLhJNd3L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71HIPyKQiEL
# Processed image_id: 71HIPyKQiEL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71pEH6cXE8L
# Processed image_id: 71pEH6cXE8L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81+PgCBM6rL
# Processed image_id: 81+PgCBM6rL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61uqI6xuJ5L
# Processed image_id: 61uqI6xuJ5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71e+NFyzWQL
# Processed image_id: 71e+NFyzWQL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71oGV2Fqa5L
# Processed image_id: 71oGV2Fqa5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 714qAnbzVML
# Processed image_id: 714qAnbzVML
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61dmfMZnd7L
# Processed image_id: 61dmfMZnd7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71fWTuWSn4L
# Processed image_id: 71fWTuWSn4L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Mq9MOCgZL
# Processed image_id: 71Mq9MOCgZL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71QclB9W0NL
# Processed image_id: 71QclB9W0NL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61oenpafdJL
# Processed image_id: 61oenpafdJL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81-zg6PFfBL
# Processed image_id: 81-zg6PFfBL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71moVbcYJTL
# Processed image_id: 71moVbcYJTL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71pk4PSGYCL
# Processed image_id: 71pk4PSGYCL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71uiPm9CKCL
# Processed image_id: 71uiPm9CKCL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71cEcibKnhL
# Processed image_id: 71cEcibKnhL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71P+bKYkPYL
# Processed image_id: 71P+bKYkPYL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71X6zDp1ovL
# Processed image_id: 71X6zDp1ovL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81hupfyK+UL
# Processed image_id: 81hupfyK+UL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71jOIfA6+vL
# Processed image_id: 71jOIfA6+vL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Ck21hZL7L
# Processed image_id: 71Ck21hZL7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81oEgRssX-L
# Processed image_id: 81oEgRssX-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71iJqMCRSaL
# Processed image_id: 71iJqMCRSaL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ZG49-PDdL
# Processed image_id: 71ZG49-PDdL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71EL84M0MQL
# Processed image_id: 71EL84M0MQL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61U83i0qoyL
# Processed image_id: 61U83i0qoyL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71d-HK8daZL
# Processed image_id: 71d-HK8daZL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 815FfYANzwL
# Processed image_id: 815FfYANzwL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 711d7mJqJdL
# Processed image_id: 711d7mJqJdL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71SUArxYmDL
# Processed image_id: 71SUArxYmDL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71SeVruZHWL
# Processed image_id: 71SeVruZHWL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61XtQ48qndL
# Processed image_id: 61XtQ48qndL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71G30siOu5L
# Processed image_id: 71G30siOu5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Zal1KpSNL
# Processed image_id: 71Zal1KpSNL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71mL8nZBJhL
# Processed image_id: 71mL8nZBJhL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81QUtWmTSzL
# Processed image_id: 81QUtWmTSzL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71aHmeb2skL
# Processed image_id: 71aHmeb2skL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 713kOkP5l+L
# Processed image_id: 713kOkP5l+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81+kz9ZkP-L
# Processed image_id: 81+kz9ZkP-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 91cGpxbfN1L
# Processed image_id: 91cGpxbfN1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81BgKxXCsoL
# Processed image_id: 81BgKxXCsoL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71kNAWv1ETL
# Processed image_id: 71kNAWv1ETL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71tH5XiHS2L
# Processed image_id: 71tH5XiHS2L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81kPGH589XL
# Processed image_id: 81kPGH589XL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71RV04rg4+L
# Processed image_id: 71RV04rg4+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71TeJUQmvrL
# Processed image_id: 71TeJUQmvrL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 710N8qq+hpL
# Processed image_id: 710N8qq+hpL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 8150CVO0UAL
# Processed image_id: 8150CVO0UAL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71T6d8A6qYL
# Processed image_id: 71T6d8A6qYL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71k4BdjWJeL
# Processed image_id: 71k4BdjWJeL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81GfzfeOTIL
# Processed image_id: 81GfzfeOTIL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81NwGFKA0cL
# Processed image_id: 81NwGFKA0cL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81-lNWEw7HL
# Processed image_id: 81-lNWEw7HL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61Z9st3ZrTL
# Processed image_id: 61Z9st3ZrTL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61QF3saKliL
# Processed image_id: 61QF3saKliL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61DThPo-IeL
# Processed image_id: 61DThPo-IeL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 51nKPLApX7L
# Processed image_id: 51nKPLApX7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71rk4f8QteL
# Processed image_id: 71rk4f8QteL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71qVzkf8orL
# Processed image_id: 71qVzkf8orL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61ulFDVFclL
# Processed image_id: 61ulFDVFclL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61pX0ZFuG6L
# Processed image_id: 61pX0ZFuG6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 810NfJXuRbL
# Processed image_id: 810NfJXuRbL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71gi7rjm7IL
# Processed image_id: 71gi7rjm7IL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71zvexkuq+L
# Processed image_id: 71zvexkuq+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71GnnJOC+mL
# Processed image_id: 71GnnJOC+mL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71phqvhT0ML
# Processed image_id: 71phqvhT0ML
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71wUywttkyL
# Processed image_id: 71wUywttkyL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61onCwb-QvL
# Processed image_id: 61onCwb-QvL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 714q2k61WIL
# Processed image_id: 714q2k61WIL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61x6AYwhNNL
# Processed image_id: 61x6AYwhNNL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71z1ZD4SljL
# Processed image_id: 71z1ZD4SljL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81a-IGo8CgL
# Processed image_id: 81a-IGo8CgL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61ib03xmqvL
# Processed image_id: 61ib03xmqvL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 711sUxJETwL
# Processed image_id: 711sUxJETwL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71jSkR2-ioL
# Processed image_id: 71jSkR2-ioL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71stuf1SPjL
# Processed image_id: 71stuf1SPjL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81SLEHs7edL
# Processed image_id: 81SLEHs7edL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ysdonjBHL
# Processed image_id: 71ysdonjBHL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71He4Qwc28L
# Processed image_id: 71He4Qwc28L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71i9PEQKPsL
# Processed image_id: 71i9PEQKPsL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71cqRD+qeDL
# Processed image_id: 71cqRD+qeDL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81+Q0G-jY2L
# Processed image_id: 81+Q0G-jY2L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 715qZK8JdrL
# Processed image_id: 715qZK8JdrL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81MPYPPnm0L
# Processed image_id: 81MPYPPnm0L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 6138bHCRwTL
# Processed image_id: 6138bHCRwTL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71vEd0D0GxL
# Processed image_id: 71vEd0D0GxL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71TfA5lHJ4L
# Processed image_id: 71TfA5lHJ4L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 717N6kVeTjL
# Processed image_id: 717N6kVeTjL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71PhS6LVEmL
# Processed image_id: 71PhS6LVEmL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81ajzHp7nhL
# Processed image_id: 81ajzHp7nhL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61J5aqVZ54L
# Processed image_id: 61J5aqVZ54L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61as9vnmZKL
# Processed image_id: 61as9vnmZKL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61-8hxrIZ4L
# Processed image_id: 61-8hxrIZ4L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61a1KzPpX+L
# Processed image_id: 61a1KzPpX+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 613a2mAg1QL
# Processed image_id: 613a2mAg1QL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71MvPayApnL
# Processed image_id: 71MvPayApnL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 711nR9nl4lL
# Processed image_id: 711nR9nl4lL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71deqXU2svL
# Processed image_id: 71deqXU2svL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71lsmOM1knL
# Processed image_id: 71lsmOM1knL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 716430QgpmL
# Processed image_id: 716430QgpmL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71AzhpUQmdL
# Processed image_id: 71AzhpUQmdL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81b5rXHxu+L
# Processed image_id: 81b5rXHxu+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61VjfdSdOJL
# Processed image_id: 61VjfdSdOJL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71VGbRXpBoL
# Processed image_id: 71VGbRXpBoL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71PArcNl7SL
# Processed image_id: 71PArcNl7SL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81gZksXeJlL
# Processed image_id: 81gZksXeJlL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61PdNUkDHYL
# Processed image_id: 61PdNUkDHYL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71f2+4gIcTL
# Processed image_id: 71f2+4gIcTL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81+eZp+DZBL
# Processed image_id: 81+eZp+DZBL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Fqc0ljObL
# Processed image_id: 71Fqc0ljObL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61XaYDsx4AL
# Processed image_id: 61XaYDsx4AL
# ...
# Sending request for image_id: 71NaAcQjz+L
# Processed image_id: 71NaAcQjz+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71zmEe1T0-L
# Processed image_id: 71zmEe1T0-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81+AT46BezL
# Processed image_id: 81+AT46BezL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71w1D72ipEL
# Processed image_id: 71w1D72ipEL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61NWMZDjD5L
# Processed image_id: 61NWMZDjD5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81SX7XlaMsL
# Processed image_id: 81SX7XlaMsL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71yDS4qV1TL
# Processed image_id: 71yDS4qV1TL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71phvI-XoaL
# Processed image_id: 71phvI-XoaL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71BgYLnkvQL
# Processed image_id: 71BgYLnkvQL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71gNcrYujoL
# Processed image_id: 71gNcrYujoL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61rrDlY4u2L
# Processed image_id: 61rrDlY4u2L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71RGwWmwy6L
# Processed image_id: 71RGwWmwy6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71TzhqgCoEL
# Processed image_id: 71TzhqgCoEL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71pUtZled3L
# Processed image_id: 71pUtZled3L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71GtYioN4SL
# Processed image_id: 71GtYioN4SL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81A7waeM7hL
# Processed image_id: 81A7waeM7hL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71DEUoMTyqL
# Processed image_id: 71DEUoMTyqL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 814-rygW1tL
# Processed image_id: 814-rygW1tL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61DVrPbSQNL
# Processed image_id: 61DVrPbSQNL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Ot6+SbiZL
# Processed image_id: 71Ot6+SbiZL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 715ZdDGVV8L
# Processed image_id: 715ZdDGVV8L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61elOKoFVDL
# Processed image_id: 61elOKoFVDL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Yic3c13ZL
# Processed image_id: 71Yic3c13ZL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71OgbwmJITL
# Processed image_id: 71OgbwmJITL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81R2VUQxTdL
# Processed image_id: 81R2VUQxTdL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Yh2Ae4C6L
# Processed image_id: 71Yh2Ae4C6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ONM0SaPHL
# Processed image_id: 71ONM0SaPHL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71PzLa9KT5L
# Processed image_id: 71PzLa9KT5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ROD-THsKL
# Processed image_id: 71ROD-THsKL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 51WVnTzl1-L
# Processed image_id: 51WVnTzl1-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 718qQCcyBnL
# Processed image_id: 718qQCcyBnL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 813HAQIevQL
# Processed image_id: 813HAQIevQL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81XYbUqS5rL
# Processed image_id: 81XYbUqS5rL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81WJhKDjLBL
# Processed image_id: 81WJhKDjLBL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71UKtmtuQjL
# Processed image_id: 71UKtmtuQjL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81EMpLMLphL
# Processed image_id: 81EMpLMLphL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71zxZosdKoL
# Processed image_id: 71zxZosdKoL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61uKGVcgIOL
# Processed image_id: 61uKGVcgIOL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81e0+bGz2fL
# Processed image_id: 81e0+bGz2fL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61H8pH0MptL
# Processed image_id: 61H8pH0MptL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 817x5OCyJEL
# Processed image_id: 817x5OCyJEL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61cCWF5Bb1L
# Processed image_id: 61cCWF5Bb1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81if0paYZFL
# Processed image_id: 81if0paYZFL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 712a+nzWuwL
# Processed image_id: 712a+nzWuwL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71JB2uMrG+L
# Processed image_id: 71JB2uMrG+L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71Jv7TBySfL
# Processed image_id: 71Jv7TBySfL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71ySxZnawGL
# Processed image_id: 71ySxZnawGL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61LlMmRAFyL
# Processed image_id: 61LlMmRAFyL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61JHC7J7yaL
# Processed image_id: 61JHC7J7yaL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81f5USdAVEL
# Processed image_id: 81f5USdAVEL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61PRZBSsf7L
# Processed image_id: 61PRZBSsf7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71OFNbdV7RL
# Processed image_id: 71OFNbdV7RL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71TTS3NSKdL
# Processed image_id: 71TTS3NSKdL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 717ZgCnxJuL
# Processed image_id: 717ZgCnxJuL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 713-RtbtYDL
# Processed image_id: 713-RtbtYDL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81HBM740pSL
# Processed image_id: 81HBM740pSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81o40TYXe0L
# Processed image_id: 81o40TYXe0L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71z57z2VrNL
# Processed image_id: 71z57z2VrNL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81sRQ5byiEL
# Processed image_id: 81sRQ5byiEL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71a51Im2KjL
# Processed image_id: 71a51Im2KjL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71vnIUXlNfL
# Processed image_id: 71vnIUXlNfL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81j1b89wjfL
# Processed image_id: 81j1b89wjfL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71qHX1jDJuL
# Processed image_id: 71qHX1jDJuL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81z7+KtG5hL
# Processed image_id: 81z7+KtG5hL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61HbDkO2iLL
# Processed image_id: 61HbDkO2iLL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61-G82nvA4L
# Processed image_id: 61-G82nvA4L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61GV3KXK2jL
# Processed image_id: 61GV3KXK2jL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71mEX9BJ-SL
# Processed image_id: 71mEX9BJ-SL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81cTdhgVZiL
# Processed image_id: 81cTdhgVZiL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 615rfVO6S3L
# Processed image_id: 615rfVO6S3L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71QRpIVIOzL
# Processed image_id: 71QRpIVIOzL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81ad3t19B-L
# Processed image_id: 81ad3t19B-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71rFfGRxAuL
# Processed image_id: 71rFfGRxAuL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81eksx4-8RL
# Processed image_id: 81eksx4-8RL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71aYlXnD3-L
# Processed image_id: 71aYlXnD3-L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71DLQifYQBL
# Processed image_id: 71DLQifYQBL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71eycIJEAgL
# Processed image_id: 71eycIJEAgL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61Z2kl1Y-oL
# Processed image_id: 61Z2kl1Y-oL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 813Q0TMN9zL
# Processed image_id: 813Q0TMN9zL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81zsgDZE1mL
# Processed image_id: 81zsgDZE1mL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81rdN-6QPrL
# Processed image_id: 81rdN-6QPrL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71zR4dztMPL
# Processed image_id: 71zR4dztMPL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71GRfgIS-FL
# Processed image_id: 71GRfgIS-FL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 91whUJVWm1L
# Processed image_id: 91whUJVWm1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61aGw-0gZ1L
# Processed image_id: 61aGw-0gZ1L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81WYwbc8z8L
# Processed image_id: 81WYwbc8z8L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71fws4GuIIL
# Processed image_id: 71fws4GuIIL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61qM-OlNfWL
# Processed image_id: 61qM-OlNfWL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71cOUrM3AHL
# Processed image_id: 71cOUrM3AHL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71u-4BqgWfL
# Processed image_id: 71u-4BqgWfL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71SmcguoFKL
# Processed image_id: 71SmcguoFKL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81C0DM7TUDL
# Processed image_id: 81C0DM7TUDL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71OZQR-pjfL
# Processed image_id: 71OZQR-pjfL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71eiktVCBdL
# Processed image_id: 71eiktVCBdL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 614Uy87B7XL
# Processed image_id: 614Uy87B7XL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61d6u3ZOwSL
# Processed image_id: 61d6u3ZOwSL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81JMh2O7m8L
# Processed image_id: 81JMh2O7m8L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 715VHoCaPxL
# Processed image_id: 715VHoCaPxL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61MNLIoRLXL
# Processed image_id: 61MNLIoRLXL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71lhgDkdnVL
# Processed image_id: 71lhgDkdnVL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71wXFVjbtBL
# Processed image_id: 71wXFVjbtBL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71aBCO7En7L
# Processed image_id: 71aBCO7En7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81-soB2ky3L
# Processed image_id: 81-soB2ky3L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81HmETL8Z9L
# Processed image_id: 81HmETL8Z9L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 41Qj6+tf1uL
# Processed image_id: 41Qj6+tf1uL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 719PpbQ0dCL
# Processed image_id: 719PpbQ0dCL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61qUWQOsc7L
# Processed image_id: 61qUWQOsc7L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81CeVG3bx3L
# Processed image_id: 81CeVG3bx3L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71lKF+rcRVL
# Processed image_id: 71lKF+rcRVL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71JxRd1cskL
# Processed image_id: 71JxRd1cskL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 718mNq7M6JL
# Processed image_id: 718mNq7M6JL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61rVQMFRGRL
# Processed image_id: 61rVQMFRGRL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81NO8WGnyDL
# Processed image_id: 81NO8WGnyDL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61lyZohdU3L
# Processed image_id: 61lyZohdU3L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71P2TPM26IL
# Processed image_id: 71P2TPM26IL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61zol556X6L
# Processed image_id: 61zol556X6L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61rxnqdcGnL
# Processed image_id: 61rxnqdcGnL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71DkxvWpyuL
# Processed image_id: 71DkxvWpyuL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71wei0WbnUL
# Processed image_id: 71wei0WbnUL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 81LgRNsLU5L
# Processed image_id: 81LgRNsLU5L
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61KGfHIo8YL
# Processed image_id: 61KGfHIo8YL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71RCQiLc7zL
# Processed image_id: 71RCQiLc7zL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 715rEV7k0XL
# Processed image_id: 715rEV7k0XL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 61YEoHf4DQL
# Processed image_id: 61YEoHf4DQL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 71rd-7giJgL
# Processed image_id: 71rd-7giJgL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 51Hqp0zWtQL
# Processed image_id: 51Hqp0zWtQL
# Sleeping 60 seconds to respect rate limits...
# Sending request for image_id: 818CNyj7jKL
# Processed image_id: 818CNyj7jKL
# Sleeping 60 seconds to respect rate limits...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 196
#     192 os.makedirs(progress_dir, exist_ok=True)
#     193 progress_file = os.path.join(progress_dir, f'progress_{current_working_filename}.txt')
# --> 196 process_records(listings_csv_path, images_csv_path, images_base_path, output_file, progress_file)
#
# Cell In[16], line 172, in process_records(listings_csv_path, images_csv_path, images_base_path, output_file, progress_file)
#     170 if requests_made < MAX_DAILY_REQUESTS:
#     171     print(f"Sleeping {DELAY_BETWEEN_REQUESTS} seconds to respect rate limits...")
# --> 172     time.sleep(DELAY_BETWEEN_REQUESTS)
#
# KeyboardInterrupt:
